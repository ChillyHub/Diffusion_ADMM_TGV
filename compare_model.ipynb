# %%
import os
import analyzing_tools as at

# %%
config_name = 'AAPM_256_ncsnpp_continuous'
problem = 'sparseview_CT_ADMM_TV_total'

vo_file_name = 'volume_198.npy'
gt_file_name = 'ground_truth_198.npy'

# %% [markdown]
# # Sparse 8 view

# %%
# view 8

volume_8views = []
method_8views = []

try:
    method = 'TV'
    root = f'./results/{config_name}/{problem}/{method}/n_view{8}/rho_{10}-lambda_{0.04}/volume/'
    volume_TV_8views, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_8views.append(volume_TV_8views)
    method_8views.append(method)
except:
    pass

try:
    method = 'TGV_3'
    root = f'./results/{config_name}/{problem}/{method}/n_view{8}/rho0_{5}-rho1_{5}-lambda_{0.04}-alpha0_{2.5}-alpha_1_{2.5}/volume/'
    volume_TGV_3_8views, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_8views.append(volume_TGV_3_8views)
    method_8views.append(method)
except:
    pass

try:
    method = 'TGV_2'
    root = f'./results/{config_name}/{problem}/{method}/n_view{8}/rho0_{5}-rho1_{5}-lambda_{0.04}-alpha0_{2.5}-alpha_1_{2.5}/volume/'
    volume_TGV_2_8views, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_8views.append(volume_TGV_2_8views)
    method_8views.append(method)
except:
    pass

try:
    method = 'TGV_1'
    root = f'./results/{config_name}/{problem}/{method}/n_view{8}/rho0_{5}-rho1_{5}-lambda_{0.04}-alpha0_{2.5}-alpha_1_{2.5}/volume/'
    volume_TGV_1_8views, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_8views.append(volume_TGV_1_8views)
    method_8views.append(method)
except:
    pass

# %%
dict_8views_list = []
for i in range(len(volume_8views)):
    reslt_8view = at.extract_slices_and_evaluate(volume_8views[i], ground_truth)
    dict_8views_list.append(at.flatten_nested_dict(reslt_8view))

data_8views_df = at.flatten_dicts_to_df(dict_8views_list, method_8views)

print(f'Num of methods: {len(data_8views_df)}')

at.table_comparison(data_8views_df, 'PSNR, SSIM')
# Out:
# Num of methods: 7

# %%
at.plot_comparison(volume_8views, method_8views, ground_truth, inset=True)

# %% [markdown]
# # Sparse 4 view

# %%
# view 4

volume_4views = []
method_4views = []

try:
    method = 'TV'
    root = f'./results/{config_name}/{problem}/{method}/n_view{4}/rho_{10}-lambda_{0.04}/volume/'
    volume_TV_4views, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_4views.append(volume_TV_4views)
    method_4views.append(method)
except:
    pass    

try:
    method = 'TGV_3'
    root = f'./results/{config_name}/{problem}/{method}/n_view{4}/rho0_{5}-rho1_{5}-lambda_{0.04}-alpha0_{2.5}-alpha_1_{2.5}/volume/'
    volume_TGV_3_4views, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_4views.append(volume_TGV_3_4views)
    method_4views.append(method)
except:
    pass

try:
    method = 'TGV_2'
    root = f'./results/{config_name}/{problem}/{method}/n_view{4}/rho0_{5}-rho1_{5}-lambda_{0.04}-alpha0_{2.5}-alpha_1_{2.5}/volume/'
    volume_TGV_2_4views, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_4views.append(volume_TGV_2_4views)
    method_4views.append(method)
except:
    pass

try:
    method = 'TGV_1'
    root = f'./results/{config_name}/{problem}/{method}/n_view{4}/rho0_{5}-rho1_{5}-lambda_{0.04}-alpha0_{2.5}-alpha_1_{2.5}/volume/'
    volume_TGV_1_4views, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_4views.append(volume_TGV_1_4views)
    method_4views.append(method)
except:
    pass

# %%
dict_4views_list = []
for i in range(len(volume_4views)):
    reslt_4view = at.extract_slices_and_evaluate(volume_4views[i], ground_truth)
    dict_4views_list.append(at.flatten_nested_dict(reslt_4view))

data_4views_df = at.flatten_dicts_to_df(dict_4views_list, method_4views)

print(f'Num of methods: {len(dict_4views_list)}')

at.table_comparison(data_4views_df, 'PSNR, SSIM')
# Out:
# Num of methods: 1

# %%
at.plot_comparison(volume_4views, method_4views, ground_truth, inset=True)

# %% [markdown]
# # Sparse 2 view

# %%
# view 2

volume_2views = []
method_2views = []

try:
    method = 'TV'
    root = f'./results/{config_name}/{problem}/{method}/n_view{2}/rho_{10}-lambda_{0.04}/volume/'
    volume_TV_2views, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_2views.append(volume_TV_2views)
    method_2views.append(method)
except:
    pass

try:
    method = 'TGV_3'
    root = f'./results/{config_name}/{problem}/{method}/n_view{2}/rho0_{5}-rho1_{5}-lambda_{0.04}-alpha0_{2.5}-alpha_1_{2.5}/volume/'
    volume_TGV_3_2views, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_2views.append(volume_TGV_3_2views)
    method_2views.append(method)
except:
    pass

try:
    method = 'TGV_2'
    root = f'./results/{config_name}/{problem}/{method}/n_view{2}/rho0_{5}-rho1_{5}-lambda_{0.04}-alpha0_{2.5}-alpha_1_{2.5}/volume/'
    volume_TGV_2_2views, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_2views.append(volume_TGV_2_2views)
    method_2views.append(method)
except:
    pass

try:
    method = 'TGV_1'
    root = f'./results/{config_name}/{problem}/{method}/n_view{2}/rho0_{5}-rho1_{5}-lambda_{0.04}-alpha0_{2.5}-alpha_1_{2.5}/volume/'
    volume_TGV_1_2views, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_2views.append(volume_TGV_1_2views)
    method_2views.append(method)
except:
    pass

# %%
dict_2views_list = []
for i in range(len(volume_2views)):
    reslt_2view = at.extract_slices_and_evaluate(volume_2views[i], ground_truth)
    dict_2views_list.append(at.flatten_nested_dict(reslt_2view))

data_2views_df = at.flatten_dicts_to_df(dict_2views_list, method_2views)

print(f'Num of methods: {len(dict_2views_list)}')

at.table_comparison(data_2views_df, 'PSNR, SSIM')
# Out:
# Num of methods: 2

# %%
at.plot_comparison(volume_2views, method_2views, ground_truth, inset=True)

# %% [markdown]
# # Limited angle 90

# %%
problem = 'limitedangle_CT_ADMM_TV_total'

# %%
# limited angle 90

volume_90angle = []
method_90angle = []

try:
    method = 'TV'
    root = f'./results/{config_name}/{problem}/{method}/n_view{90}/rho_{10}-lambda_{0.04}/volume/'
    volume_TV_90angle, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_90angle.append(volume_TV_90angle)
    method_90angle.append(method)
except:
    pass

try:
    method = 'TGV_3'
    root = f'./results/{config_name}/{problem}/{method}/n_view{90}/rho0_{5}-rho1_{5}-lambda_{0.04}-alpha0_{2.5}-alpha_1_{2.5}/volume/'
    volume_TGV_3_90angle, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_90angle.append(volume_TGV_3_90angle)
    method_90angle.append(method)
except:
    pass

try:
    method = 'TGV_2'
    root = f'./results/{config_name}/{problem}/{method}/n_view{90}/rho0_{5}-rho1_{5}-lambda_{0.04}-alpha0_{2.5}-alpha_1_{2.5}/volume/'
    volume_TGV_2_90angle, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_90angle.append(volume_TGV_2_90angle)
    method_90angle.append(method)
except:
    pass

try:
    method = 'TGV_1'
    root = f'./results/{config_name}/{problem}/{method}/n_view{90}/rho0_{5}-rho1_{5}-lambda_{0.04}-alpha0_{2.5}-alpha_1_{2.5}/volume/'
    volume_TGV_1_90angle, ground_truth = at.load_volume(root, vo_file_name, gt_file_name)
    volume_90angle.append(volume_TGV_1_90angle)
    method_90angle.append(method)
except:
    pass

# %%
dict_90angle_list = []
for i in range(len(volume_90angle)):
    reslt_90angle = at.extract_slices_and_evaluate(volume_90angle[i], ground_truth)
    dict_90angle_list.append(at.flatten_nested_dict(reslt_90angle))

data_90angle_df = at.flatten_dicts_to_df(dict_90angle_list, method_90angle)

print(f'Num of methods: {len(dict_90angle_list)}')

at.table_comparison(data_90angle_df, 'PSNR, SSIM')
# Out:
# Num of methods: 1

# %%
at.plot_comparison(volume_90angle, method_90angle, ground_truth, inset=True)
